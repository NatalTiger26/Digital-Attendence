# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import shutil
from PIL import Image
import random

# %%
def remove_some_files():     # removes extra files so that each celebrity has 80 images
    os.chdir('Dataset')
    celebrity_list = os.listdir()
    for i in celebrity_list:
        os.chdir(i)
        flag = 0
        for j in os.listdir():
            if (flag>=80):
                os.remove(j)
            flag +=1
        os.chdir('../')
    os.chdir('../')


def remane_correctly():       # to rename the files with numbers
    os.chdir('Dataset')
    celebrity_list = os.listdir()
    for i in celebrity_list:
        os.chdir(i)
        flag = 0
        for j in os.listdir():
            new_name = i[5:] + "_" + str(flag) + ".jpg"
            os.rename(j, new_name)
            flag += 1
        os.chdir('../')
    os.chdir('../')


def number_of_files():           # function listing the number of files in each folder
    os.chdir('Dataset')
    celebrity_list = os.listdir()
    num_images = []
    folder_paths = []
    for i in celebrity_list:
        os.chdir(i)
        num_images.append(len(os.listdir()))
        folder_paths.append(os.getcwd())
        print(i, len(os.listdir()))
        os.chdir('../')
    os.chdir('../')
    print(min(num_images))


def Create_full_data():            # To make a folder that has copies of all the pics from all the celebrities 
    os.mkdir("Full Data")
    os.chdir("Full Data")
    destination = os.getcwd()
    os.chdir("..")
    os.chdir('Dataset')
                        
    celebrity_list = os.listdir()
    folder_paths = []
    for i in celebrity_list:
        os.chdir(i)
        folder_paths.append(os.getcwd())
        os.chdir('../')
    os.chdir('../')

    for source_path in folder_paths:
        for f in os.listdir(source_path):
            src_path = os.path.join(source_path, f)
            dst_path = os.path.join(destination, f)
            shutil.copyfile(src_path, dst_path)
        

def resize_dataset():             # This will resize our images in Dataset to (size, size) 
    size = 128
    os.chdir("Dataset")
    for i in os.listdir():
        os.chdir(i)
        for j in range(80):
            im = Image.open(i + "_" + str(j) + ".jpg")
            newsize = (size, size)
            im1 = im.resize(newsize)
            im1.save(i + "_" + str(j) + ".jpg")
        os.chdir("..")
    os.chdir("..")


def collage_maker():           # This makes a 4x4 collages using the given images of celebrities in random places
    os.chdir("Dataset")
    celebrity_list = os.listdir()
    for i in range(80):
        random.shuffle(celebrity_list)
        Vconcat = []
        for j in range(4):
            Hconcat = []
            for k in range(4):
                Hconcat.append(cv2.imread(celebrity_list[4*j + k] + "\\" + celebrity_list[4*j + k] + "_" + str(i) + ".jpg"))
            Vconcat.append(cv2.hconcat(Hconcat))
        img = cv2.vconcat(Vconcat)
        os.chdir("../Collages")
        dest_path = "Collage_" + str(i) + ".jpg"
        cv2.imwrite(dest_path, img)
        os.chdir("../Dataset")
    os.chdir("..")

# %%
collage_maker()
