# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %%
# Initialize the variables
image_width = 128
image_length = 128
total_pixels = image_width*image_length

# %%
os.chdir('Dataset')
celebrity_list = os.listdir()
count = 0
avg_face_vector = []
for i in celebrity_list:
    os.chdir(i)
    face_vector = []
    flag = 0
    pics_75 = 0
    for j in os.listdir():
        if pics_75 < 75:
            face_image = cv2.cvtColor(cv2.imread(j), cv2.COLOR_RGB2GRAY)
            face_image = cv2.resize(face_image, (image_width, image_length))
            face_image = face_image.reshape(total_pixels,)
            face_vector.append(face_image)
            if flag ==0:
                flag = 1
                plt.imshow(np.array(face_image.reshape(image_width,image_length)),cmap='gray')
                plt.title(i + ' Sample Face')
                plt.show()
        pics_75 += 1
    face_vector = np.asarray(face_vector)
    face_vector = face_vector.transpose()
    #STEP2: Normalize the face vectors by calculating the average face vector and subtracting it from each vector
    avg_face_vector.append(np.mean(face_vector,axis=1))
    
    # avg_face_vector[count] = avg_face_vector[count] * 10000 / sum(avg_face_vector[count])
    # print(sum(avg_face_vector[count]))
    
    plt.imshow(avg_face_vector[count].reshape(image_width,image_length),cmap='gray')
    plt.title(i + ' Mean Face')
    plt.show()
    avg_face_vector[count] = avg_face_vector[count].reshape(face_vector.shape[0], 1)
    count += 1
    
    os.chdir('..')
os.chdir('..')

# %%
def distance_test (file, is_image = 0):
    distance = []
    if is_image == 1:
        test_img = file
    else:
        test_img = cv2.imread(file)
    
    test_img = cv2.cvtColor(test_img, cv2.COLOR_RGB2GRAY)   
    test_img= cv2.resize(test_img, (image_width, image_length))
    test_img = test_img.reshape(total_pixels, 1)
    
 
    
    count = 0
    for i in avg_face_vector:
        dist = np.linalg.norm(i - test_img)
        distance.append([celebrity_list[count], dist])
        count += 1
    
    distance.sort(key = lambda x: x[1]) 
                                        
    return distance

# %%
os.chdir("Dataset")
for name in celebrity_list:
    for number in range(75, 80, 1):
        dist = distance_test(name + "\\" + name + "_" + str(number) + ".jpg")
        print("Actual name: ", name)
        print("Prediction : ", dist[0][0])
        count = 0
        for k in range(len(dist)):
            if dist[k][0] == name:
                print("Rank of the actual name : ", count + 1)
                print("Percentage difference in distance of actual vs prediction : ", 100 * (dist[k][1] - dist[0][1])/dist[k][1])
            count += 1
        print("\n")
os.chdir("..")
# Out:
# Actual name:  Adriana Lima
# Prediction :  Jennifer Lawrence
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  5.61786408532017
#
#
# Actual name:  Adriana Lima
# Prediction :  Adriana Lima
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Adriana Lima
# Prediction :  Adriana Lima
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Adriana Lima
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  15
# Percentage difference in distance of actual vs prediction :  18.467410003887274
#
#
# Actual name:  Adriana Lima
# Prediction :  Rihanna
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  9.926820308172358
#
#
# Actual name:  barack obama
# Prediction :  margot robbie
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  10.329575170052177
#
#
# Actual name:  barack obama
# Prediction :  Rihanna
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  6.265971979867464
#
#
# Actual name:  barack obama
# Prediction :  Dwayne Johnson
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  1.0795519372629738
#
#
# Actual name:  barack obama
# Prediction :  margot robbie
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  17.083363087336025
#
#
# Actual name:  barack obama
# Prediction :  Lionel Messi
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  4.2247152520283136
#
#
# Actual name:  Chris Hemsworth
# Prediction :  Christian Bale
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  0.685819628220001
#
#
# Actual name:  Chris Hemsworth
# Prediction :  Dwayne Johnson
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  5.207871551997017
#
#
# Actual name:  Chris Hemsworth
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.9353428675897161
#
#
# Actual name:  Chris Hemsworth
# Prediction :  Adriana Lima
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  6.828393876720952
#
#
# Actual name:  Chris Hemsworth
# Prediction :  Rihanna
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  20.737605427622334
#
#
# Actual name:  Christian Bale
# Prediction :  Adriana Lima
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  19.88475971825455
#
#
# Actual name:  Christian Bale
# Prediction :  Cristiano Ronaldo
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  2.6850263224391884
#
#
# Actual name:  Christian Bale
# Prediction :  Zendaya
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  1.4587580943049423
#
#
# Actual name:  Christian Bale
# Prediction :  Rihanna
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  18.181053779138207
#
#
# Actual name:  Christian Bale
# Prediction :  Rihanna
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  20.24472676244819
#
#
# Actual name:  Cristiano Ronaldo
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  5.165476467739619
#
#
# Actual name:  Cristiano Ronaldo
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  5.750132985205016
#
#
# Actual name:  Cristiano Ronaldo
# Prediction :  Rihanna
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  25.110661776535785
#
#
# Actual name:  Cristiano Ronaldo
# Prediction :  Adriana Lima
# Rank of the actual name :  11
# Percentage difference in distance of actual vs prediction :  7.460946129481558
#
#
# Actual name:  Cristiano Ronaldo
# Prediction :  margot robbie
# Rank of the actual name :  5
# Percentage difference in distance of actual vs prediction :  2.811267085749732
#
#
# Actual name:  Dwayne Johnson
# Prediction :  Cristiano Ronaldo
# Rank of the actual name :  11
# Percentage difference in distance of actual vs prediction :  14.301576618834439
#
#
# Actual name:  Dwayne Johnson
# Prediction :  Cristiano Ronaldo
# Rank of the actual name :  10
# Percentage difference in distance of actual vs prediction :  9.472826119956887
#
#
# Actual name:  Dwayne Johnson
# Prediction :  Jeremy Renner
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  8.33692229725502
#
#
# Actual name:  Dwayne Johnson
# Prediction :  margot robbie
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  1.9265183164212525
#
#
# Actual name:  Dwayne Johnson
# Prediction :  Dwayne Johnson
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Jennifer Lawrence
# Prediction :  Adriana Lima
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  24.82135768054105
#
#
# Actual name:  Jennifer Lawrence
# Prediction :  Leonardo DiCaprio
# Rank of the actual name :  5
# Percentage difference in distance of actual vs prediction :  9.143032747298392
#
#
# Actual name:  Jennifer Lawrence
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  6.128271529652006
#
#
# Actual name:  Jennifer Lawrence
# Prediction :  margot robbie
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  1.535308094784486
#
#
# Actual name:  Jennifer Lawrence
# Prediction :  Cristiano Ronaldo
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  5.8536088233070585
#
#
# Actual name:  Jeremy Renner
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  5
# Percentage difference in distance of actual vs prediction :  9.112151535067857
#
#
# Actual name:  Jeremy Renner
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  7.1605844084676
#
#
# Actual name:  Jeremy Renner
# Prediction :  Rihanna
# Rank of the actual name :  10
# Percentage difference in distance of actual vs prediction :  31.582428076181078
#
#
# Actual name:  Jeremy Renner
# Prediction :  Leonardo DiCaprio
# Rank of the actual name :  11
# Percentage difference in distance of actual vs prediction :  22.95591226131861
#
#
# Actual name:  Jeremy Renner
# Prediction :  Chris Hemsworth
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.5244045682829334
#
#
# Actual name:  Leonardo DiCaprio
# Prediction :  Jennifer Lawrence
# Rank of the actual name :  11
# Percentage difference in distance of actual vs prediction :  13.668572732968935
#
#
# Actual name:  Leonardo DiCaprio
# Prediction :  Adriana Lima
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  8.313562693610324
#
#
# Actual name:  Leonardo DiCaprio
# Prediction :  Chris Hemsworth
# Rank of the actual name :  11
# Percentage difference in distance of actual vs prediction :  10.599861344872696
#
#
# Actual name:  Leonardo DiCaprio
# Prediction :  Christian Bale
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  2.894642624416324
#
#
# Actual name:  Leonardo DiCaprio
# Prediction :  Rihanna
# Rank of the actual name :  6
# Percentage difference in distance of actual vs prediction :  8.344164879633274
#
#
# Actual name:  Lionel Messi
# Prediction :  Rihanna
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  9.164269286924577
#
#
# Actual name:  Lionel Messi
# Prediction :  Chris Hemsworth
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  1.091291768490507
#
#
# Actual name:  Lionel Messi
# Prediction :  Lionel Messi
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Lionel Messi
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  13
# Percentage difference in distance of actual vs prediction :  35.639018129015966
#
#
# Actual name:  Lionel Messi
# Prediction :  Lionel Messi
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  margot robbie
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  3.012265436909426
#
#
# Actual name:  margot robbie
# Prediction :  margot robbie
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  margot robbie
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.8284807349700912
#
#
# Actual name:  margot robbie
# Prediction :  Jennifer Lawrence
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  4.261617222378084
#
#
# Actual name:  margot robbie
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.1735574978626438
#
#
# Actual name:  Rihanna
# Prediction :  Selena Gomez
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.7204595324358382
#
#
# Actual name:  Rihanna
# Prediction :  Adriana Lima
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  5.633699557441494
#
#
# Actual name:  Rihanna
# Prediction :  Rihanna
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Rihanna
# Prediction :  Rihanna
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Rihanna
# Prediction :  Adriana Lima
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  2.6564082307593235
#
#
# Actual name:  Selena Gomez
# Prediction :  Leonardo DiCaprio
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  6.985927024524087
#
#
# Actual name:  Selena Gomez
# Prediction :  Christian Bale
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  0.6177035156394738
#
#
# Actual name:  Selena Gomez
# Prediction :  Zendaya
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  1.6151645237302639
#
#
# Actual name:  Selena Gomez
# Prediction :  Zendaya
# Rank of the actual name :  4
# Percentage difference in distance of actual vs prediction :  1.9814350762452055
#
#
# Actual name:  Selena Gomez
# Prediction :  Rihanna
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  8.820726731871805
#
#
# Actual name:  Shakira Isabel Mebarak
# Prediction :  Leonardo DiCaprio
# Rank of the actual name :  15
# Percentage difference in distance of actual vs prediction :  23.040741534843992
#
#
# Actual name:  Shakira Isabel Mebarak
# Prediction :  Jennifer Lawrence
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  6.895777754543816
#
#
# Actual name:  Shakira Isabel Mebarak
# Prediction :  Chris Hemsworth
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  8.102660925726799
#
#
# Actual name:  Shakira Isabel Mebarak
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Shakira Isabel Mebarak
# Prediction :  Taylor Swift
# Rank of the actual name :  2
# Percentage difference in distance of actual vs prediction :  2.7403416828264313
#
#
# Actual name:  Taylor Swift
# Prediction :  Taylor Swift
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Taylor Swift
# Prediction :  Jennifer Lawrence
# Rank of the actual name :  7
# Percentage difference in distance of actual vs prediction :  5.893340404451282
#
#
# Actual name:  Taylor Swift
# Prediction :  Selena Gomez
# Rank of the actual name :  8
# Percentage difference in distance of actual vs prediction :  20.099786954904697
#
#
# Actual name:  Taylor Swift
# Prediction :  Rihanna
# Rank of the actual name :  9
# Percentage difference in distance of actual vs prediction :  22.232561789163334
#
#
# Actual name:  Taylor Swift
# Prediction :  Dwayne Johnson
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  7.8462480421078515
#
#
# Actual name:  Zendaya
# Prediction :  Jeremy Renner
# Rank of the actual name :  9
# Percentage difference in distance of actual vs prediction :  5.047298815844139
#
#
# Actual name:  Zendaya
# Prediction :  Zendaya
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Zendaya
# Prediction :  Zendaya
# Rank of the actual name :  1
# Percentage difference in distance of actual vs prediction :  0.0
#
#
# Actual name:  Zendaya
# Prediction :  Adriana Lima
# Rank of the actual name :  3
# Percentage difference in distance of actual vs prediction :  7.3254729383505195
#
#
# Actual name:  Zendaya
# Prediction :  Shakira Isabel Mebarak
# Rank of the actual name :  13
# Percentage difference in distance of actual vs prediction :  23.2576165497235

# %%
distance_test("Chris.jpeg")
# Out:
# [['Dwayne Johnson', 9227.591893754778],
#  ['margot robbie', 9233.617508252717],
#  ['Jeremy Renner', 9574.650461389063],
#  ['Shakira Isabel Mebarak', 9602.162528865858],
#  ['Chris Hemsworth', 9650.648902535],
#  ['Taylor Swift', 9747.665838042118],
#  ['barack obama', 9997.578594110786],
#  ['Cristiano Ronaldo', 10250.785863415545],
#  ['Jennifer Lawrence', 10269.22720100095],
#  ['Christian Bale', 10856.520221712131],
#  ['Lionel Messi', 10901.808163982096],
#  ['Leonardo DiCaprio', 11023.742677693454],
#  ['Zendaya', 11210.852593161682],
#  ['Selena Gomez', 11511.113501748358],
#  ['Adriana Lima', 12038.3014644721],
#  ['Rihanna', 12140.37584946291]]

# %%
# Reading the image
img = cv2.imread(r'Collages/Collage_75.jpg')
  
# Converting image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Loading the required haar-cascade xml classifier file
haar_cascade = cv2.CascadeClassifier('Haarcascade_frontalface_default.xml')
  
# Applying the face detection method on the grayscale image

faces_rect = haar_cascade.detectMultiScale(gray_img, 1.05, 7)
# Iterating through rectangles of detected faces
#for (x, y, w, h) in faces_rect:
    #cv2.rectangle(img, (x, y), (x+w, y+h), (127, 0, 255), 2)
cv2.imshow('Detected faces', img)
cv2.destroyAllWindows()

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x23B2928E910>

# %%
#Testing on the Collage
for i in range(len(faces_rect)):
    testing_img=img[faces_rect[i][0]:faces_rect[i][0]+faces_rect[i][2],faces_rect[i][1]:faces_rect[i][1]+faces_rect[i][3]]
    str = "Prediction : " + distance_test(testing_img, 1)[0][0]

    testing_img = cv2.cvtColor(testing_img, cv2.COLOR_RGB2GRAY)
    plt.imshow(testing_img,cmap='gray')
    plt.title(str)
    plt.show()
